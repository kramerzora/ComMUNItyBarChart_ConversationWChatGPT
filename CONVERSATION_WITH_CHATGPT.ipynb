# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.5

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.bar(years, turnout_percentages, color=color, alpha=0.6, label='Turnout Percentage')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', label='Votes Needed')
ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.5

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.4  # Increase bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)

# Add annotations for votes needed
for i, v in enumerate(votes_needed):
    ax1.text(years[i], turnout_percentages[i] + 2, f'{int(v):,}', ha='center', color='black')

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', label='Votes Needed')
ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.51

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.6  # Increase bar width for thicker bars
x = np.arange(len(years))
bars = ax1.bar(x - bar_width / 2, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.set_xticks(x)
ax1.set_xticklabels(years)
ax1.tick_params(axis='y', labelcolor=color)

# Add annotations for votes needed
for i, v in enumerate(votes_needed):
    ax1.text(x[i] - bar_width / 2, turnout_percentages[i] + 2, f'{int(v):,}', ha='center', color='black')

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.bar(x + bar_width / 2, votes_needed, bar_width, color=color, alpha=0.6, label='Votes Needed')
ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.5

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.4  # Bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year


# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=2, label='Votes Needed')

# Add annotations for votes needed next to the line plot
for i, v in enumerate(votes_needed):
    ax2.text(years[i], v, f'{int(v):,}', color=color, ha='left', va='center')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.5

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.6  # Increase bar width for thicker bars
x = np.arange(len(years))
bars = ax1.bar(x - bar_width / 2, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.set_xticks(x)
ax1.set_xticklabels(years)
ax1.tick_params(axis='y', labelcolor=color)

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', label='Votes Needed', linestyle='-', linewidth=2)  # Line plot for votes needed
ax2.tick_params(axis='y', labelcolor=color)

# Add annotations for votes needed
for i, v in enumerate(votes_needed):
    ax2.text(years[i], v, f'{int(v):,}', color=color, ha='left', va='bottom')

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.5

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.6  # Increase bar width for thicker bars
x = np.arange(len(years))
bars = ax1.bar(x - bar_width / 2, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.set_xticks(x)
ax1.set_xticklabels(years)
ax1.tick_params(axis='y', labelcolor=color)

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', label='Votes Needed', linestyle='-', linewidth=2)  # Line plot for votes needed
ax2.tick_params(axis='y', labelcolor=color)

# Add annotations for votes needed
for i, v in enumerate(votes_needed):
    ax2.text(years[i], v + 0.02 * max(votes_needed), f'{int(v):,}', color=color, ha='center', va='bottom')

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.5

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.4  # Bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year


# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=2, label='Votes Needed')

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, ha='right', va='center')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.5

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.4  # Bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year


# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=2, label='Votes Needed')

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, ha='right', va='center')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1.15))  # Move ax1 legend up
ax2.legend(loc='upper left', bbox_to_anchor=(0, 1.05))  # Position ax2 legend below ax1 legend

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.5

# Predict 2024 turnout using linear interpolation
x = np.array(years)
y = np.array(turnout_percentages)
predicted_2024_turnout = np.interp(2024, x, y)
years.append(2024)
turnout_percentages.append(predicted_2024_turnout)

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.4  # Bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year

# Add annotations for votes needed
for i, v in enumerate(votes_needed):
    ax1.text(years[i], turnout_percentages[i]  ha='center', color='black')

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=2, label='Votes Needed')

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, ha='right', va='center')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1.15))  # Move ax1 legend up
ax2.legend(loc='upper left', bbox_to_anchor=(0, 1.05))  # Position ax2 legend below ax1 legend

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()
# Out:
#   Cell In[65], line 34
#     ax1.text(years[i], turnout_percentages[i]  ha='center', color='black')
#                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.5

# Predict 2024 turnout using linear interpolation
x = np.array(years)
y = np.array(turnout_percentages)
predicted_2024_turnout = np.interp(2024, x, y)
years.append(2024)
turnout_percentages.append(predicted_2024_turnout)

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.4  # Bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year

# Add annotations for votes needed
for i, v in enumerate(votes_needed):
    ax1.text(years[i], turnout_percentages[i] + 2, f'{int(v):,}', ha='center', color='black')

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=2, label='Votes Needed')

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, ha='right', va='center')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1.15))  # Move ax1 legend up
ax2.legend(loc='upper left', bbox_to_anchor=(0, 1.05))  # Position ax2 legend below ax1 legend

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020, 2024]
turnout_percentages = [67, 74, 81, 73, 80, 86]  # Data for years 2000 to 2020
total_voters = 500000
votes_needed_percentage = 0.5

# Predict 2024 turnout using linear interpolation
x = np.array(years[:-1])  # Exclude 2024 for interpolation
y = np.array(turnout_percentages[:-1])  # Exclude 2024 for interpolation
predicted_2024_turnout = np.interp(2024, x, y)
turnout_percentages.append(predicted_2024_turnout)

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = 'tab:blue'
bar_width = 0.4  # Bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year

# Add annotations for voter turnout percentages above the bar graph
for i, v in enumerate(turnout_percentages):
    ax1.text(years[i], v + 1, f'{v}%', ha='center', color='black')

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=2, label='Votes Needed')

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, ha='right', va='center')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1.15))  # Move ax1 legend up
ax2.legend(loc='upper left', bbox_to_anchor=(0, 1.05))  # Position ax2 legend below ax1 legend

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 13
#      11 x = np.array(years[:-1])  # Exclude 2024 for interpolation
#      12 y = np.array(turnout_percentages[:-1])  # Exclude 2024 for interpolation
# ---> 13 predicted_2024_turnout = np.interp(2024, x, y)
#      14 turnout_percentages.append(predicted_2024_turnout)
#      16 # Calculate votes needed to win for each year
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:1599, in interp(x, xp, fp, left, right, period)
#    1596     xp = np.concatenate((xp[-1:]-period, xp, xp[0:1]+period))
#    1597     fp = np.concatenate((fp[-1:], fp, fp[0:1]))
# -> 1599 return interp_func(x, xp, fp, left, right)
#
# ValueError: fp and xp are not of the same length.

# %%
import matplotlib.pyplot as plt
import numpy as np



# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020]
turnout_percentages = [67, 74, 81, 73, 80, 86]
total_voters = 500000
votes_needed_percentage = 0.51

# Predict 2024 turnout using linear interpolation
x = np.array(years)
y = np.array(turnout_percentages)
predicted_2024_turnout = np.interp(2024, x, y)

# Extend the data for 2024
years.append(2024)
turnout_percentages.append(predicted_2024_turnout)

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax1.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar plot for voter turnout percentages
color = '#398f39'
bar_width = 2  # Bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year', fontweight='bold')
ax1.set_ylabel('Turnout Percentage (%)', color=color, fontweight='bold')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year

# Add annotations for voter turnout percentages above the bar graph
for i, v in enumerate(turnout_percentages):
    ax1.text(years[i], v + 1, f'{v}%', ha='center', color='black')

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = '#de533c'
ax2.set_ylabel('Votes Needed', color=color, fontweight='bold')
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=2, label='Votes Needed')

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, ha='right', va='center')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1))  # Move ax1 legend up
ax2.legend(loc='upper left', bbox_to_anchor=(0, .93))  # Position ax2 legend below ax1 legend

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Use DejaVu Sans font
plt.rcParams['font.family'] = 'DejaVu Sans'

# Data for voter turnout and votes needed to win
years = [2000, 2004, 2008, 2012, 2016, 2020, 2024]
turnout_percentages = [67, 74, 81, 73, 80, 86]  # Data for years 2000 to 2020
total_voters = 500000
votes_needed_percentage = 0.5

# Predict 2024 turnout using linear interpolation
x = np.array(years[:-1])  # Exclude 2024 for interpolation
y = np.array(turnout_percentages[:-1])  # Exclude 2024 for interpolation
predicted_2024_turnout = np.interp(2024, x, y)
turnout_percentages.append(predicted_2024_turnout)

# Calculate votes needed to win for each year
votes_needed = [total_voters * (turnout / 100) * votes_needed_percentage for turnout in turnout_percentages]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for voter turnout percentages
color = '#1c4872'  # Updated bar color
bar_width = 0.4  # Bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year')
ax1.set_ylabel('Turnout Percentage (%)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year

# Add annotations for voter turnout percentages above the bar graph
for i, v in enumerate(turnout_percentages):
    ax1.text(years[i], v + 1, f'{v}%', ha='center', color='black')

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Votes Needed', color=color)
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=2, label='Votes Needed')

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, ha='right', va='center')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1.15))  # Move ax1 legend up
ax2.legend(loc='upper left', bbox_to_anchor=(0, 1.05))  # Position ax2 legend below ax1 legend

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[129], line 16
#      14 x = np.array(years[:-1])  # Exclude 2024 for interpolation
#      15 y = np.array(turnout_percentages[:-1])  # Exclude 2024 for interpolation
# ---> 16 predicted_2024_turnout = np.interp(2024, x, y)
#      17 turnout_percentages.append(predicted_2024_turnout)
#      19 # Calculate votes needed to win for each year
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:1599, in interp(x, xp, fp, left, right, period)
#    1596     xp = np.concatenate((xp[-1:]-period, xp, xp[0:1]+period))
#    1597     fp = np.concatenate((fp[-1:], fp, fp[0:1]))
# -> 1599 return interp_func(x, xp, fp, left, right)
#
# ValueError: fp and xp are not of the same length.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for voter turnout and votes needed to win
years = [2012, 2016, 2020]
turnout_percentages = [73, 80, 86]
total_voters_per_year = [502000, 513000, 505000]  # Total voters for 2012, 2016, and 2020
votes_needed_percentage = 0.51

# Predict 2024 turnout using linear interpolation
x = np.array(years)
y = np.array(turnout_percentages)
predicted_2024_turnout = np.interp(2024, x, y)

# Extend the data for 2024
years.append(2024)
turnout_percentages.append(predicted_2024_turnout)
total_voters_per_year.append(np.interp(2024, x, total_voters_per_year))  # Estimate total voters for 2024

# Calculate votes needed to win for each year
votes_needed = [total_voters_per_year[i] * (turnout / 100) * votes_needed_percentage for i, turnout in enumerate(turnout_percentages)]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax1.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar plot for voter turnout percentages
color = '#398f39'
bar_width = 2  # Bar width
bars = ax1.bar(years[:-1], turnout_percentages[:-1], bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year', fontweight='bold')
ax1.set_ylabel('Turnout Percentage (%)', color=color, fontweight='bold')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year

# Add annotations for voter turnout percentages above the bar graph
for i, v in enumerate(turnout_percentages[:-1]):
    ax1.text(years[i], v + 1, f'{v}%', ha='center', color='black')

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = '#de533c'
ax2.set_ylabel('Votes Needed', color=color, fontweight='bold')
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=2, label='Votes Needed')

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, ha='right', va='center')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1))  # Move ax1 legend up
ax2.legend(loc='upper left', bbox_to_anchor=(0, .93))  # Position ax2 legend below ax1 legend

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set font to Arial
plt.rcParams['font.family'] = 'Arial'

# Data for voter turnout and votes needed to win
years = [2012, 2016, 2020]
turnout_percentages = [73, 80, 86]
total_voters_per_year = [502000, 513000, 500000]  # Total voters for 2012, 2016, and 2020
votes_needed_percentage = 0.51

# Predict 2024 turnout using linear interpolation
x = np.array(years)
y = np.array(turnout_percentages)
predicted_2024_turnout = np.interp(2024, x, y)

# Extend the data for 2024
years.append(2024)
turnout_percentages.append(predicted_2024_turnout)
total_voters_per_year.append(np.interp(2024, x, total_voters_per_year))  # Estimate total voters for 2024

# Calculate votes needed to win for each year
votes_needed = [total_voters_per_year[i] * (turnout / 100) * votes_needed_percentage for i, turnout in enumerate(turnout_percentages)]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax1.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar plot for voter turnout percentages
color = '#398f39'
bar_width = 2  # Bar width
bars = ax1.bar(years[:-1], turnout_percentages[:-1], bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year', size = 10.5)
ax1.set_ylabel('Turnout Percentage (%)', color=color, size = 10.5)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year

# Add annotations for voter turnout percentages above the bar graph
for i, v in enumerate(turnout_percentages[:-1]):
    ax1.text(years[i], v + 1, f'{v}%', ha='center', color='black', fontweight='bold', size = 10.5)

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = '#de533c'
ax2.set_ylabel('Votes Needed', color=color,  size = 10.5)
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=3, label='Votes Needed')

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, fontweight='bold', size = 10.5, ha='right', va='bottom')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1))  # Move ax1 legend up
ax2.legend(loc='upper left', bbox_to_anchor=(0, .93))  # Position ax2 legend below ax1 legend

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year', fontweight='bold', size = 13)
plt.tight_layout()
plt.savefig('voter_turnout_votes_needed6.jpg', format='jpg', dpi=300)
plt.show()

 # Save with 300 dpi for high quality

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Calculate voter turnout percentages and votes needed to win for each year
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax1.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar plot for voter turnout percentages
color = '#398f39'
bar_width = 2  # Bar width
bars = ax1.bar(years, turnout_percentages, bar_width, color=color, alpha=0.6, label='Turnout Percentage')
ax1.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax1.set_ylabel('Turnout Percentage (%)', color=color, fontweight='bold', fontsize=14, family='Arial')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(years)  # Ensure tick marks are placed at each year

# Add annotations for voter turnout percentages above the bar graph
for i, v in enumerate(turnout_percentages):
    ax1.text(years[i], v + 1, f'{v:.1f}%', ha='center', color='black', fontsize=12, family='Arial')

# Create a secondary y-axis for votes needed to win
ax2 = ax1.twinx()
color = '#de533c'
ax2.set_ylabel('Votes Needed', color=color, fontweight='bold', fontsize=14, family='Arial')
ax2.plot(years, votes_needed, color=color, marker='o', linestyle='-', linewidth=4, label='Votes Needed')  # Increased line thickness

# Add annotations for votes needed next to the line plot, moved further left
for i, v in enumerate(votes_needed):
    ax2.text(years[i] - 0.3, v, f'{int(v):,}', color=color, ha='right', va='center', fontsize=12, family='Arial')

ax2.tick_params(axis='y', labelcolor=color)

# Add legends
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1))  # Move ax1 legend up
ax2.legend(loc='upper left', bbox_to_anchor=(0, .93))  # Position ax2 legend below ax1 legend

# Title and layout
plt.title('Voter Turnout Percentages and Votes Needed to Win by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()



# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Calculate voter turnout percentages and votes needed to win for each year
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed) in enumerate(zip(total_voters, voter_turnout, votes_needed)):
    ax.text(index[i] - bar_width, reg + 10000, f'{reg:,}', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 10000, f'{turnout:,}', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 10000, f'{int(needed):,}', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='upper left')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

# Save as JPEG


# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Predict 2024 turnout and total voters using linear interpolation
x = np.array(years)
y_voters = np.array(total_voters)
y_turnout = np.array(voter_turnout)

# Predict total voters for 2024
predicted_total_voters_2024 = 506769

# Predict turnout percentage for 2024
predicted_turnout_2024 = np.interp(2024, x, y_turnout)
predicted_turnout_percentage_2024 = (predicted_turnout_2024 / predicted_total_voters_2024) * 100

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed) in enumerate(zip(total_voters, voter_turnout, votes_needed)):
    ax.text(index[i] - bar_width, reg + 10000, f'{reg:,}', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 10000, f'{turnout:,}', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 10000, f'{int(needed):,}', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()



# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Predict 2024 turnout and total voters using linear interpolation
x = np.array(years)
y_voters = np.array(total_voters)
y_turnout = np.array(voter_turnout)

# Predict total voters for 2024
predicted_total_voters_2024 = 506769

# Predict turnout percentage for 2024
predicted_turnout_2024 = np.interp(2024, x, y_turnout)
predicted_turnout_percentage_2024 = (predicted_turnout_2024 / predicted_total_voters_2024) * 100

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed) in enumerate(zip(total_voters, voter_turnout, votes_needed)):
    ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 5, f'{turnout}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 5, f'{needed}K', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

# Save as JPEG
plt.savefig('voter_registration_turnout_votes_needed_rounded.jpg', format='jpg', dpi=300)  # Save with 300 dpi for high quality

# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Fixed 2024 turnout percentage
turnout_percentage_2024 = 86
predicted_total_voters_2024 = 506769
predicted_turnout_2024 = (turnout_percentage_2024 / 100) * predicted_total_voters_2024

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed) in enumerate(zip(total_voters, voter_turnout, votes_needed)):
    ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 5, f'{turnout}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 5, f'{needed}K', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()



# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Fixed 2024 turnout percentage
turnout_percentage_2024 = 86
predicted_total_voters_2024 = 506769
predicted_turnout_2024 = (turnout_percentage_2024 / 100) * predicted_total_voters_2024

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed, turnout_percentage) in enumerate(zip(total_voters, voter_turnout, votes_needed, turnout_percentages)):
    ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 5, f'{turnout}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 5, f'{needed}K', ha='center', color='black', fontsize=10, family='Arial')
    # Add percentage turnout annotations
    ax.text(index[i], turnout - 15, f'{turnout_percentage:.1f}%', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed for Simple Majority by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

# Save as JPEG
plt.savefig('voter_registration_turnout_votes_needed_with_percentage.jpg', format='jpg', dpi=300)  # Save with 300 dpi for high quality

# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Fixed 2024 turnout percentage
turnout_percentage_2024 = 86
predicted_total_voters_2024 = 506769
predicted_turnout_2024 = (turnout_percentage_2024 / 100) * predicted_total_voters_2024

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed, turnout_percentage) in enumerate(zip(total_voters, voter_turnout, votes_needed, turnout_percentages)):
    ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 5, f'{turnout}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 5, f'{needed}K', ha='center', color='black', fontsize=10, family='Arial')
    # Add percentage turnout annotations, rounded to the nearest whole number
    ax.text(index[i], turnout - 15, f'{int(round(turnout_percentage))}%', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed for Simple Majority by General Election Year (2000 to 2024)', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

plt.savefig('CoMUNItyBars2.jpg', format='jpg', dpi=300)  # Save with 300 dpi for high quality


# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Fixed 2024 turnout percentage
turnout_percentage_2024 = 86
predicted_total_voters_2024 = 506769
predicted_turnout_2024 = (turnout_percentage_2024 / 100) * predicted_total_voters_2024

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed, turnout_percentage) in enumerate(zip(total_voters, voter_turnout, votes_needed, turnout_percentages)):
    ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 5, f'{turnout}K**', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 5, f'{needed}K**', ha='center', color='black', fontsize=10, family='Arial')
    # Add percentage turnout annotations, rounded to the nearest whole number
    ax.text(index[i], turnout - 15, f'{int(round(turnout_percentage))}%', ha='center', color='black', fontsize=10, family='Arial')

# Add asterisk and footnote for 2024 data
ax.text(index[-1], total_voters[-1] + 5, f'{total_voters[-1]}K*', ha='center', color='black', fontsize=10, family='Arial')
ax.text(index[-1], voter_turnout[-1] + 5, f'{voter_turnout[-1]}K**', ha='center', color='black', fontsize=10, family='Arial')
ax.text(index[-1] + bar_width, votes_needed[-1] + 5, f'{votes_needed[-1]}K**', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

# Add footnotes
footnotes = (
    "Source: Historical Voter Data\n"
    "Predicted 2024 total registration based on current data.\n"
    "Turnout percentage for 2024 assumed to be 86%.\n"
    "Votes needed to win calculated as 51% of the total voter turnout.\n"
    "* Data for 2024 is as of 07/18/2024.\n"
    "** Values for 2024 calculated assuming voter turnout remains at 86%."
)
plt.figtext(0.1, -0.3, footnotes, ha='left', va='top', fontsize=10, family='Arial', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

# Save as JPEG
plt.savefig('voter_registration_turnout_votes_needed_with_percentage_and_footnotes.jpg', format='jpg', dpi=300)  # Save with 300 dpi for high quality

# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Fixed 2024 turnout percentage
turnout_percentage_2024 = 86
predicted_total_voters_2024 = 506769
predicted_turnout_2024 = (turnout_percentage_2024 / 100) * predicted_total_voters_2024

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed, turnout_percentage) in enumerate(zip(total_voters, voter_turnout, votes_needed, turnout_percentages)):
    ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 5, f'{turnout}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 5, f'{needed}K', ha='center', color='black', fontsize=10, family='Arial')
    # Add percentage turnout annotations, rounded to the nearest whole number
    ax.text(index[i], turnout - 15, f'{int(round(turnout_percentage))}%', ha='center', color='black', fontsize=10, family='Arial')

# Add asterisks and footnote for 2024 data
ax.text(index[-1], total_voters[-1] + 5, f'{total_voters[-1]}K*', ha='center', color='black', fontsize=10, family='Arial')
ax.text(index[-1], voter_turnout[-1] + 5, f'{voter_turnout[-1]}K**', ha='center', color='black', fontsize=10, family='Arial')
ax.text(index[-1] + bar_width, votes_needed[-1] + 5, f'{votes_needed[-1]}K**', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

# Add footnotes
footnotes = (
    "Source: Historical Voter Data\n"
    "Predicted 2024 total registration based on current data.\n"
    "Turnout percentage for 2024 assumed to be 86%.\n"
    "Votes needed to win calculated as 51% of the total voter turnout.\n"
    "* Data for 2024 is as of 07/18/2024.\n"
    "** Values for 2024 calculated assuming voter turnout remains at 86%."
)
plt.figtext(0.1, -0.3, footnotes, ha='left', va='top', fontsize=10, family='Arial', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

# Save as JPEG
plt.savefig('voter_registration_turnout_votes_needed_with_percentage_and_footnotes.jpg', format='jpg', dpi=300)  # Save with 300 dpi for high quality

# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Fixed 2024 turnout percentage
turnout_percentage_2024 = 86
predicted_total_voters_2024 = 506769
predicted_turnout_2024 = (turnout_percentage_2024 / 100) * predicted_total_voters_2024

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed, turnout_percentage) in enumerate(zip(total_voters, voter_turnout, votes_needed, turnout_percentages)):
    ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 5, f'{turnout}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 5, f'{needed}K', ha='center', color='black', fontsize=10, family='Arial')
    # Add percentage turnout annotations, rounded to the nearest whole number
    ax.text(index[i], turnout - 15, f'{int(round(turnout_percentage))}%', ha='center', color='black', fontsize=10, family='Arial')

# Add asterisks and footnote for 2024 data
ax.text(index[-1] - bar_width, total_voters[-1] + 5, f'{total_voters[-1]}K*', ha='center', color='black', fontsize=10, family='Arial')
ax.text(index[-1], voter_turnout[-1] + 5, f'{voter_turnout[-1]}K**', ha='center', color='black', fontsize=10, family='Arial')
ax.text(index[-1] + bar_width, votes_needed[-1] + 5, f'{votes_needed[-1]}K**', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

# Add footnotes
footnotes = (
    "Source: Historical Voter Data\n"
    "Predicted 2024 total registration based on current data.\n"
    "Turnout percentage for 2024 assumed to be 86%.\n"
    "Votes needed to win calculated as 51% of the total voter turnout.\n"
    "* Data for 2024 is as of 07/18/2024.\n"
    "** Values for 2024 calculated assuming voter turnout remains at 86%."
)
plt.figtext(0.1, -0.3, footnotes, ha='left', va='top', fontsize=10, family='Arial', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

# Save as JPEG
plt.savefig('voter_registration_turnout_votes_needed_with_percentage_and_footnotes.jpg', format='jpg', dpi=300)  # Save with 300 dpi for high quality

# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Fixed 2024 turnout percentage
turnout_percentage_2024 = 86
predicted_total_voters_2024 = 506769
predicted_turnout_2024 = (turnout_percentage_2024 / 100) * predicted_total_voters_2024

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed, turnout_percentage) in enumerate(zip(total_voters, voter_turnout, votes_needed, turnout_percentages)):
    ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i], turnout + 5, f'{turnout}K', ha='center', color='black', fontsize=10, family='Arial')
    ax.text(index[i] + bar_width, needed + 5, f'{needed}K', ha='center', color='black', fontsize=10, family='Arial')
    # Add percentage turnout annotations, rounded to the nearest whole number
    ax.text(index[i], turnout - 15, f'{int(round(turnout_percentage))}%', ha='center', color='black', fontsize=10, family='Arial')

# Add asterisks and footnote for 2024 data
ax.text(index[-1] - bar_width, total_voters[-1] + 5, f'{total_voters[-1]}K*', ha='center', color='black', fontsize=10, family='Arial')
ax.text(index[-1], voter_turnout[-1] + 5, f'{voter_turnout[-1]}K**', ha='center', color='black', fontsize=10, family='Arial')
ax.text(index[-1] + bar_width, votes_needed[-1] + 5, f'{votes_needed[-1]}K**', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

# Add footnotes
footnotes = (
    "Source: Historical Voter Data\n"
    "Predicted 2024 total registration based on current data.\n"
    "Turnout percentage for 2024 assumed to be 86%.\n"
    "Votes needed to win calculated as 51% of the total voter turnout.\n"
    "* Data for 2024 is as of 07/18/2024.\n"
    "** Values for 2024 calculated assuming voter turnout remains at 86%."
)
plt.figtext(0.1, -0.3, footnotes, ha='left', va='top', fontsize=10, family='Arial', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

# Save as JPEG

# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Fixed 2024 turnout percentage
turnout_percentage_2024 = 86
predicted_total_voters_2024 = 506769
predicted_turnout_2024 = (turnout_percentage_2024 / 100) * predicted_total_voters_2024

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed, turnout_percentage) in enumerate(zip(total_voters, voter_turnout, votes_needed, turnout_percentages)):
    if years[i] == 2024:
        # Add asterisks only for 2024
        ax.text(index[i] - bar_width, reg + 5, f'{reg}K*', ha='center', color='black', fontsize=10, family='Arial')
        ax.text(index[i], turnout + 5, f'{turnout}K**', ha='center', color='black', fontsize=10, family='Arial')
        ax.text(index[i] + bar_width, needed + 5, f'{needed}K**', ha='center', color='black', fontsize=10, family='Arial')
    else:
        # Normal annotations
        ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
        ax.text(index[i], turnout + 5, f'{turnout}K', ha='center', color='black', fontsize=10, family='Arial')
        ax.text(index[i] + bar_width, needed + 5, f'{needed}K', ha='center', color='black', fontsize=10, family='Arial')
    # Add percentage turnout annotations, rounded to the nearest whole number
    ax.text(index[i], turnout - 15, f'{int(round(turnout_percentage))}%', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed by Year', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

# Add footnotes
footnotes = (
    "Source: Historical Voter Data\n"
    "Predicted 2024 total registration based on current data.\n"
    "Turnout percentage for 2024 assumed to be 86%.\n"
    "Votes needed to win calculated as 51% of the total voter turnout.\n"
    "* Data for 2024 is as of 07/18/2024.\n"
    "** Values for 2024 calculated assuming voter turnout remains at 86%."
)
plt.figtext(0.1, -0.3, footnotes, ha='left', va='top', fontsize=10, family='Arial', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

 

# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = [2000, 2004, 2008, 2012, 2016, 2020]
total_voters = [486636, 486937, 477651, 502841, 513573, 521099]
voter_turnout = [324031, 361822, 388112, 388112, 388112, 449866]
votes_needed_percentage = 0.51

# Fixed 2024 turnout percentage
turnout_percentage_2024 = 86
predicted_total_voters_2024 = 506769
predicted_turnout_2024 = (turnout_percentage_2024 / 100) * predicted_total_voters_2024

# Extend the data for 2024
years.append(2024)
total_voters.append(predicted_total_voters_2024)
voter_turnout.append(predicted_turnout_2024)
turnout_percentages = [turnout / total * 100 for turnout, total in zip(voter_turnout, total_voters)]
votes_needed = [total * (turnout / 100) * votes_needed_percentage for total, turnout in zip(total_voters, turnout_percentages)]

# Convert to thousands and round
total_voters = [round(v / 1000) for v in total_voters]
voter_turnout = [round(v / 1000) for v in voter_turnout]
votes_needed = [round(v / 1000) for v in votes_needed]

# Create figure and axes
fig, ax = plt.subplots(figsize=(14, 7))

# Set background color for the figure and axes
fig.patch.set_facecolor('#fbf3dc')  # Background color for the figure
ax.set_facecolor('#fbf3dc')  # Background color for the axes

# Bar width and positions
bar_width = 0.25
index = np.arange(len(years))

# Plotting the bars
bars1 = ax.bar(index - bar_width, total_voters, bar_width, color='#1c4872', label='Total Registration')
bars2 = ax.bar(index, voter_turnout, bar_width, color='#398f39', label='Voter Turnout')
bars3 = ax.bar(index + bar_width, votes_needed, bar_width, color='#de533c', label='Votes Needed')

# Labeling the axes
ax.set_xlabel('Year', fontweight='bold', fontsize=14, family='Arial')
ax.set_ylabel('Count (Thousands)', fontweight='bold', fontsize=14, family='Arial')
ax.set_xticks(index)
ax.set_xticklabels(years)

# Add annotations for bars
for i, (reg, turnout, needed, turnout_percentage) in enumerate(zip(total_voters, voter_turnout, votes_needed, turnout_percentages)):
    if years[i] == 2024:
        # Add asterisks only for 2024
        ax.text(index[i] - bar_width, reg + 5, f'{reg}K*', ha='center', color='black', fontsize=10, family='Arial')
        ax.text(index[i], turnout + 5, f'{turnout}K**', ha='center', color='black', fontsize=10, family='Arial')
        ax.text(index[i] + bar_width, needed + 5, f'{needed}K**', ha='center', color='black', fontsize=10, family='Arial')
    else:
        # Normal annotations
        ax.text(index[i] - bar_width, reg + 5, f'{reg}K', ha='center', color='black', fontsize=10, family='Arial')
        ax.text(index[i], turnout + 5, f'{turnout}K', ha='center', color='black', fontsize=10, family='Arial')
        ax.text(index[i] + bar_width, needed + 5, f'{needed}K', ha='center', color='black', fontsize=10, family='Arial')
    # Add percentage turnout annotations, rounded to the nearest whole number
    ax.text(index[i], turnout - 15, f'{int(round(turnout_percentage))}%', ha='center', color='black', fontsize=10, family='Arial')

# Add legends
ax.legend(loc='lower right')

# Title and layout
plt.title('Voter Registration, Turnout, and Votes Needed for Simple Majority by General Election Year (2000 to 2024)', fontweight='bold', fontsize=16, family='Arial')
plt.tight_layout()

# Add footnotes just underneath the graph
footnotes = (
    "Source: sfelections.org\n"
    "* Data for 2024 is as of 07/18/2024.\n"
    "** Values for 2024 voter turnout and votes needed calculated assuming voter turnout remains at 86%."
)
plt.figtext(0, 0.05, footnotes, ha='left', va='top', fontsize=10, family='Arial', color='black')

plt.savefig('CoMUNItyBars7.jpg', format='jpg', dpi=300)  # Save with 300 dpi for high quality

# Show the plot
plt.show()

# Close the figure to free up resources
plt.close(fig)
